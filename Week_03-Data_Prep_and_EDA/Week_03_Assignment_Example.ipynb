# %% [markdown]
# <a href="https://colab.research.google.com/github/gitmystuff/DTSC4050/blob/main/Week_03-Data_Prep_and_EDA/Week_03_Assignment_Example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 03 - Assignment Example

# %% [markdown]
# Please provide the shape of your dataset (once in a Pandas dataframe), the info, the first five rows, and simple descriptive statistics (if possible).
#
# What follows are several examples:
# * Example 1: Traditional Linear Regression Analysis
# * Example 2: Traditional Logistic Regression (Classification) Analysis
# * Example 3: A little more creative with the use of AI

# %% [markdown]
# ## Example 1: Traditional Linear Regression Analysis
#
# Forest Fires: This dataset models the area burned in forest fires based on meteorological and other variables.  Predicting the burned area (a continuous variable) from things like temperature, rainfall, wind speed, and the day of the week is a good linear regression exercise.

# %%
# pip install ucimlrepo

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
forest_fires = fetch_ucirepo(id=162)

# data (as pandas dataframes)
X = forest_fires.data.features
y = forest_fires.data.targets

# metadata
print(forest_fires.metadata)

# variable information
print(forest_fires.variables)
# Out:
# {'uci_id': 162, 'name': 'Forest Fires', 'repository_url': 'https://archive.ics.uci.edu/dataset/162/forest+fires', 'data_url': 'https://archive.ics.uci.edu/static/public/162/data.csv', 'abstract': 'This is a difficult regression task, where the aim is to predict the burned area of forest fires, in the northeast region of Portugal, by using meteorological and other data (see details at: http://www.dsi.uminho.pt/~pcortez/forestfires).', 'area': 'Climate and Environment', 'tasks': ['Regression'], 'characteristics': ['Multivariate'], 'num_instances': 517, 'num_features': 12, 'feature_types': ['Real'], 'demographics': [], 'target_col': ['area'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 2007, 'last_updated': 'Thu Jan 11 2024', 'dataset_doi': '10.24432/C5D88D', 'creators': ['Paulo Cortez', 'Anbal Morais'], 'intro_paper': {'ID': 368, 'type': 'NATIVE', 'title': 'A data mining approach to predict forest fires using meteorological 
# ...

# %%
# create dataframe from uci url
import pandas as pd

df = pd.read_csv(forest_fires.metadata.data_url)
print(df.shape)
print(df.info())
df.head()
# Out:
# (517, 13)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       517 non-null    int64
#  1   Y       517 non-null    int64
#  2   month   517 non-null    object
#  3   day     517 non-null    object
#  4   FFMC    517 non-null    float64
#  5   DMC     517 non-null    float64
#  6   DC      517 non-null    float64
#  7   ISI     517 non-null    float64
#  8   temp    517 non-null    float64
#  9   RH      517 non-null    int64
#  10  wind    517 non-null    float64
#  11  rain    517 non-null    float64
#  12  area    517 non-null    float64
# dtypes: float64(8), int64(3), object(2)
# memory usage: 52.6+ KB
# None
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# ...

# %%
df.describe()
# Out:
#                 X           Y        FFMC         DMC          DC         ISI  \
# count  517.000000  517.000000  517.000000  517.000000  517.000000  517.000000
# mean     4.669246    4.299807   90.644681  110.872340  547.940039    9.021663
# std      2.313778    1.229900    5.520111   64.046482  248.066192    4.559477
# min      1.000000    2.000000   18.700000    1.100000    7.900000    0.000000
# 25%      3.000000    4.000000   90.200000   68.600000  437.700000    6.500000
# 50%      4.000000    4.000000   91.600000  108.300000  664.200000    8.400000
# 75%      7.000000    5.000000   92.900000  142.400000  713.900000   10.800000
# max      9.000000    9.000000   96.200000  291.300000  860.600000   56.100000
#
#              temp          RH        wind        rain         area
# count  517.000000  517.000000  517.000000  517.000000   517.000000
# mean    18.889168   44.288201    4.017602    0.021663    12.847292
# ...

# %% [markdown]
# ## Example 2: Traditional Logistic Regression (Classification) Analysis
#
# Wine Quality (Red or White - Classification Version):  Will create a classification problem from the wine quality datasets by defining a threshold for "high quality" vs. "low quality."

# %%
from ucimlrepo import fetch_ucirepo
import pandas as pd

data = fetch_ucirepo(id=186)

df = pd.read_csv(data.metadata.data_url)

# create new dependent variable called quality_category based on some threshold
threshold = 7
df['quality_category'] = (df['quality'] >= threshold).astype(int) # 1 for high, 0 for low

print(df.shape)
print(df.info())
df.head()
# Out:
# (6497, 14)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed_acidity         6497 non-null   float64
#  1   volatile_acidity      6497 non-null   float64
#  2   citric_acid           6497 non-null   float64
#  3   residual_sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free_sulfur_dioxide   6497 non-null   float64
#  6   total_sulfur_dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
#  12  color                 6497 non-null   object
#  13  quality_category      6497 non-null   int64
# ...

# %%
df.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %% [markdown]
# ## Example 3: Creating a Scenario with AI
#
# AI Generated Scenario
#
# **Coffee Shop Customer Satisfaction:**
#
# * **Scenario:**  You own a coffee shop and want to understand the factors that influence customer satisfaction and spending.
# * **Data Generation:**
#     * **Customer Profiles:** Generate customers with attributes like age, income, coffee preference (strength, type), frequency of visits, and sensitivity to price.
#     * **Shop Features:**  Create variables for things like ambiance (music, décor), Wi-Fi quality, waiting time, drink quality, and price.
#     * **Satisfaction Score:**  Develop a formula to calculate a satisfaction score based on how well the shop features align with customer preferences.  Include some random noise to simulate real-world variability.
# * **Analysis:**  Use regression to analyze the impact of different factors on satisfaction or spending. You could use classification to predict whether a customer will become a regular.
#
# **Important Considerations for Synthetic Data:**
#
# * **Realism:**  Try to make your data as realistic as possible by considering real-world distributions and relationships between variables.
# * **Bias:** Be aware of potential biases you might introduce in your data generation process and try to mitigate them.
# * **Documentation:** Clearly document how you generated your data and any assumptions you made. This is crucial for the reproducibility and interpretability of your analysis.

# %% [markdown]
# The AI generated the following code to create the data I need but there were some gotchas with the random choice function where I had to manually enter the percentages. For example
#
# <pre>
# drink_types = ['Espresso', 'Americano', 'Latte', 'Cappuccino', 'Other']
# drink_type = np.random.choice(drink_types, size=n_rows, p=[.2, .15, .3, .25, .1])  # Drink type
# </pre>
#
# I had to manually enter a list of probabilites for p  `[.2, .15, .3, .25, .1]`

# %%
# Code provided by AI
import pandas as pd
import numpy as np

# Set random seed for reproducibility
np.random.seed(42)

# Number of rows
n_rows = 200

# --- Generate independent variables ---

# Numerical - Continuous
age = np.random.normal(loc=35, scale=10, size=n_rows).astype(int)  # Age
distance = np.random.exponential(scale=5, size=n_rows)  # Distance (miles)
time_spent = np.random.gamma(shape=2, scale=15, size=n_rows).astype(int)  # Time spent (minutes)
spending = np.random.gamma(shape=1.5, scale=5, size=n_rows).round(2)  # Spending ($)

# Numerical - Discrete
visits_per_month = np.random.poisson(lam=2, size=n_rows)  # Visits per month
loyalty_points = np.random.negative_binomial(n=5, p=0.3, size=n_rows) * 10  # Loyalty points

# Code provided by AI
import pandas as pd
import numpy as np

# Set random seed for reproducibility
np.random.seed(42)

# Number of rows
n_rows = 200

# --- Generate independent variables ---

# Numerical - Continuous
age = np.random.normal(loc=35, scale=10, size=n_rows).astype(int)  # Age
distance = np.random.exponential(scale=5, size=n_rows)  # Distance (miles)
time_spent = np.random.gamma(shape=2, scale=15, size=n_rows).astype(int)  # Time spent (minutes)
spending = np.random.gamma(shape=1.5, scale=5, size=n_rows).round(2)  # Spending ($)

# Numerical - Discrete
visits_per_month = np.random.poisson(lam=2, size=n_rows)  # Visits per month
loyalty_points = np.random.negative_binomial(n=5, p=0.3, size=n_rows) * 10  # Loyalty points

# Categorical - Nominal
days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
day = np.random.choice(days, size=n_rows)  # Day of week
payment_methods = ['Cash', 'Credit Card', 'Mobile Pay']
payment_method = np.random.choice(payment_methods, size=n_rows)  # Payment method

# Categorical - Ordinal
drink_types = ['Espresso', 'Americano', 'Latte', 'Cappuccino', 'Other']
drink_type = np.random.choice(drink_types, size=n_rows)  # Drink type
sizes = ['Small', 'Medium', 'Large']
size = np.random.choice(sizes, size=n_rows)  # Size
wifi_qualities = ['Excellent', 'Good', 'Fair', 'Poor']
wifi_quality = np.random.choice(wifi_qualities, size=n_rows)  # Wi-Fi quality

# --- Create DataFrame ---
df = pd.DataFrame({
    'Age': age,
    'Distance': distance,
    'TimeSpent': time_spent,
    'Spending': spending,
    'VisitsPerMonth': visits_per_month,
    'LoyaltyPoints': loyalty_points,
    'Day': day,
    'PaymentMethod': payment_method,
    'DrinkType': drink_type,
    'Size': size,
    'WifiQuality': wifi_quality
})

# --- Introduce multicollinearity ---

# Distance and TimeSpent
df['TimeSpent'] = df['TimeSpent'] + (10 - df['Distance']).astype(int)

# Spending and DrinkType
df['Spending'] = df['Spending'] + np.where(df['DrinkType'] == 'Latte', 2, 0)

# Spending and Size
df['Spending'] = df['Spending'] + np.where(df['Size'] == 'Medium', 1, np.where(df['Size'] == 'Large', 2, 0))

# --- Calculate satisfaction score ---

def calculate_satisfaction(row):
    score = 0
    score += (10 - row['Distance']) / 10 * 20  # Distance (closer = more satisfied)
    score += row['TimeSpent'] / 60 * 10  # Time spent (longer = more satisfied)
    score += row['Spending'] / 10 * 15  # Spending (more = more satisfied)
    score += np.where(row['DrinkType'] == 'Latte', 10, 0)  # Latte drinkers are more satisfied
    score += {'Excellent': 20, 'Good': 15, 'Fair': 5, 'Poor': 0}[row['WifiQuality']]  # Wi-Fi quality
    score += np.random.normal(0, 10)  # Add some random noise
    return score

df['SatisfactionScore'] = df.apply(calculate_satisfaction, axis=1)

# --- Classify satisfaction ---
df['Satisfaction'] = np.where(df['SatisfactionScore'] >= 60, 'Satisfied', 'Not Satisfied')

# --- Introduce missing values ---
for col in df.columns:
    df.loc[df.sample(frac=0.05).index, col] = np.nan

# --- Drop SatisfactionScore ---
# df = df.drop(columns=['SatisfactionScore']) will keep this to test for multicollinearity

# --- Save to CSV ---
df.to_csv('coffee_shop_customer_satisfaction.csv', index=False) # this appears in my session folder to the left

print("Dataset generated and saved to 'coffee_shop_customer_satisfaction.csv'")

# Categorical - Ordinal
drink_types = ['Espresso', 'Americano', 'Latte', 'Cappuccino', 'Other']
drink_type = np.random.choice(drink_types, size=n_rows, p=[.2, .15, .3, .25, .1])  # Drink type
sizes = ['Small', 'Medium', 'Large']
size = np.random.choice(sizes, size=n_rows, p=[.3, .5, .2])  # Size
wifi_qualities = ['Excellent', 'Good', 'Fair', 'Poor']
wifi_quality = np.random.choice(wifi_qualities, size=n_rows, p=[.25, .25, .25, .25])  # Wi-Fi quality

# --- Create DataFrame ---
df = pd.DataFrame({
    'Age': age,
    'Distance': distance,
    'TimeSpent': time_spent,
    'Spending': spending,
    'VisitsPerMonth': visits_per_month,
    'LoyaltyPoints': loyalty_points,
    'Day': day,
    'PaymentMethod': payment_method,
    'DrinkType': drink_type,
    'Size': size,
    'WifiQuality': wifi_quality
})

# --- Introduce multicollinearity ---

# Distance and TimeSpent
df['TimeSpent'] = df['TimeSpent'] + (10 - df['Distance']).astype(int)

# Spending and DrinkType
df['Spending'] = df['Spending'] + np.where(df['DrinkType'] == 'Latte', 2, 0)

# Spending and Size
df['Spending'] = df['Spending'] + np.where(df['Size'] == 'Medium', 1, np.where(df['Size'] == 'Large', 2, 0))

# --- Calculate satisfaction score ---

def calculate_satisfaction(row):
    score = 0
    score += (10 - row['Distance']) / 10 * 20  # Distance (closer = more satisfied)
    score += row['TimeSpent'] / 60 * 10  # Time spent (longer = more satisfied)
    score += row['Spending'] / 10 * 15  # Spending (more = more satisfied)
    score += np.where(row['DrinkType'] == 'Latte', 10, 0)  # Latte drinkers are more satisfied
    score += {'Excellent': 20, 'Good': 15, 'Fair': 5, 'Poor': 0}[row['WifiQuality']]  # Wi-Fi quality
    score += np.random.normal(0, 10)  # Add some random noise
    return score

df['SatisfactionScore'] = df.apply(calculate_satisfaction, axis=1)

# --- Classify satisfaction ---
df['Satisfaction'] = np.where(df['SatisfactionScore'] >= 60, 'Satisfied', 'Not Satisfied')

# --- Introduce missing values ---
for col in df.columns:
    df.loc[df.sample(frac=0.05).index, col] = np.nan

# --- Drop SatisfactionScore ---
# df = df.drop(columns=['SatisfactionScore']) will keep this to test for multicollinearity

# --- Save to CSV ---
df.to_csv('coffee_shop_customer_satisfaction.csv', index=False) # this appears in my session folder to the left

print("Dataset generated and saved to 'coffee_shop_customer_satisfaction.csv'")
# Out:
# Dataset generated and saved to 'coffee_shop_customer_satisfaction.csv'
# Dataset generated and saved to 'coffee_shop_customer_satisfaction.csv'

# %%
import pandas as pd

df = pd.read_csv('coffee_shop_customer_satisfaction.csv')
print(df.shape)
print(df.info())
df.head()
# Out:
# (200, 13)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Age                190 non-null    float64
#  1   Distance           190 non-null    float64
#  2   TimeSpent          190 non-null    float64
#  3   Spending           190 non-null    float64
#  4   VisitsPerMonth     190 non-null    float64
#  5   LoyaltyPoints      190 non-null    float64
#  6   Day                190 non-null    object
#  7   PaymentMethod      190 non-null    object
#  8   DrinkType          190 non-null    object
#  9   Size               190 non-null    object
#  10  WifiQuality        190 non-null    object
#  11  SatisfactionScore  190 non-null    float64
#  12  Satisfaction       190 non-null    object
# dtypes: float64(7), object(6)
# memory usage: 20.4+ KB
# None
# ...

# %%
df.describe()
# Out:
#               Age    Distance   TimeSpent    Spending  VisitsPerMonth  \
# count  190.000000  190.000000  190.000000  190.000000      190.000000
# mean    34.000000    4.876363   34.047368    9.546211        2.026316
# std      9.060642    4.619657   22.660197    5.497541        1.430707
# min      8.000000    0.054484    0.000000    0.470000        0.000000
# 25%     27.000000    1.121008   17.250000    5.492500        1.000000
# 50%     34.000000    3.605961   30.000000    8.615000        2.000000
# 75%     39.750000    7.017248   45.000000   12.130000        3.000000
# max     59.000000   23.285024  122.000000   29.050000        6.000000
#
#        LoyaltyPoints  SatisfactionScore
# count     190.000000         190.000000
# mean      116.842105          44.261301
# std        63.141114          19.174116
# min        10.000000          -2.906957
# 25%        70.000000          29.837511
# 50%       110.000000          43.437645
# 75%       157.500000          57.828595
# ...
